# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-280419/DATA-SCIENCE-PRACTICAL/blob/main/PRACTICAL_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({"roll no":[6236,6237,6272,6273,6273],
                 "name":["Akash","Ritik","sarthak","Abhinay","Abhinay"],
                 "Address":["C.B.D","vashi","turba","panvel","panvel"],
                 "marks":[90,80,70,60,60]})
print(df)
# Out:
#    roll no     name Address  marks
# 0     6236    Akash   C.B.D     90
# 1     6237    Ritik   vashi     80
# 2     6272  sarthak   turba     70
# 3     6273  Abhinay  panvel     60
# 4     6273  Abhinay  panvel     60

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    roll no   name  Address  marks
# 0    False  False    False  False
# 1    False  False    False  False
# 2    False  False    False  False
# 3    False  False    False  False>

# %%
df.describe()
# Out:
#            roll no      marks
# count     4.000000   4.000000
# mean   6254.500000  75.000000
# std      20.792627  12.909944
# min    6236.000000  60.000000
# 25%    6236.750000  67.500000
# 50%    6254.500000  75.000000
# 75%    6272.250000  82.500000
# max    6273.000000  90.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['roll no'].plot(kind='hist', bins=20, title='roll no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['marks'].plot(kind='hist', bins=20, title='marks')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df.describe(include="object")
# Out:
#          name Address
# count       4       4
# unique      4       4
# top     Akash   C.B.D
# freq        1       1

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   roll no  4 non-null      int64
#  1   name     4 non-null      object
#  2   Address  4 non-null      object
#  3   marks    4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# roll no    4
# name       4
# Address    4
# marks      4
# dtype: int64

# %%
df.value_counts()
# Out:
# roll no  name     Address  marks
# 6273     Abhinay  panvel   60       2
# 6236     Akash    C.B.D    90       1
# 6237     Ritik    vashi    80       1
# 6272     sarthak  turba    70       1
# dtype: int64

# %%
df["name"].value_counts()
# Out:
# Abhinay    2
# Akash      1
# Ritik      1
# sarthak    1
# Name: name, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-19-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           roll no     marks
# roll no  1.000000 -0.921132
# marks   -0.921132  1.000000

# %%
import seaborn as sns
cor=df.corr()
sns.heatmap(cor,annot=True,fmt=".2f",cmap="coolwarm")
# Out:
# <ipython-input-33-16f2760a023e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-34-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# roll no    392.7
# marks      170.0
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-35-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll no    6258.2
# marks        72.0
# dtype: float64

# %%
df.min()
# Out:
# roll no       6236
# name       Abhinay
# Address      C.B.D
# marks           60
# dtype: object

# %%
df["marks"].var()
# Out:
# 170.0

# %%
df.cov()
# Out:
# <ipython-input-38-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#          roll no  marks
# roll no    392.7 -238.0
# marks     -238.0  170.0
