# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-280419/DATA-SCIENCE-PRACTICAL/blob/main/pratical8%2C9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#Load and Display Head of Titanic Dataset
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Display Count of Null Values in Each Column of the DataFrame
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#To fill null values in the age column
mean_age=df['age'].mean()
df['Age Mean']=df['age'].fillna(mean_age)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.value_counts('deck').nunique()
# Out:
# 7

# %%
mode_deck=df['deck'].mode()[0]
df['deck mode']=df['deck'].fillna(mode_deck)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
mode_embarked=df['embarked'].mode()[0]
df['embarked mode']=df['embarked'].fillna(mode_embarked)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
mode_embark_town 	=df['embark_town'].mode()[0]
df['embark_town mode']=df['embark_town'].fillna(mode_embark_town 	)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.select_dtypes("int")
# Out:
#      survived  pclass  sibsp  parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %%
df.select_dtypes("object")
# Out:
#         sex embarked    who  embark_town alive embarked mode embark_town mode
# 0      male        S    man  Southampton    no             S      Southampton
# 1    female        C  woman    Cherbourg   yes             C        Cherbourg
# 2    female        S  woman  Southampton   yes             S      Southampton
# 3    female        S  woman  Southampton   yes             S      Southampton
# 4      male        S    man  Southampton    no             S      Southampton
# ..      ...      ...    ...          ...   ...           ...              ...
# 886    male        S    man  Southampton    no             S      Southampton
# 887  female        S  woman  Southampton   yes             S      Southampton
# 888  female        S  woman  Southampton    no             S      Southampton
# 889    male        C    man    Cherbourg   yes             C        Cherbourg
# 890    male        Q    man   Queenstown    no             Q       Queenstown
#
# [891 rows x 7 columns]

# %%
sns.histplot(data=df,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.boxplot(data=df,x="sex")
# Out:
# <Axes: xlabel='sex'>

# %%
sns.countplot(data=df,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.violinplot(data=df,x="sex")
# Out:
# <Axes: xlabel='sex'>

# %%
import matplotlib.pyplot as plt
plt.hist(data=df,x="sex",bins=5)
# Out:
# (array([577.,   0.,   0.,   0., 314.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(df["fare"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e899e905c00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e899e9060b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e899e905960>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e899e9065f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e899e906890>],
#  'means': []}

# %%
plt.violinplot(df["fare"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7e899e2dd390>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7e899e2dd3c0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7e899e2dd9c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7e899e2ddd20>}

# %%
sns.scatterplot(data=df,x="sex",y="age",hue="alive")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.lineplot(data=df,x="sex",y="age",hue="alive")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(data=df,x="sex",y="age",hue="alive")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.histplot(data=df,x="sex",y="fare",hue="alive")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(data=df,x="sex",y="fare",hue="alive")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>
